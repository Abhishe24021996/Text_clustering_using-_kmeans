# %%
import re
from nltk.corpus import stopwords
from string import punctuation
from material_cleaner.cleaner import text_cleaner
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("last_5.csv")
data.head()
# Out:
#    Unnamed: 0                         doi        pmid  \
# 0           0   10.1377/hlthaff.2014.0743  25489031.0
# 1           1     10.7508/ibj.2015.03.009  26025954.0
# 2           2     10.3748/wjg.v21.i8.2504  25741161.0
# 3           3  10.4103/ijnmr.IJNMR_174_18  31333744.0
# 4           4   10.1136/bmjpo-2017-000172  29637168.0
#
#                                                 text  \
# 0  Go to:AbstractThe ACA establishes “essential h...
# 1  Go to:AbstractBackground:The variable numbers ...
# 2  Go to:AbstractAIM: To evaluate the safety and ...
# 3  Go to:AbstractBackground:Cancer is the second ...
# 4  Go to:AbstractObjectiveTo describe the experie...
#
#                                                 link    label1
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  abstract
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  abstract

# %%
def structure_1(text):
    text = text.lower()
    #substituting the known irregularities as from scraping
    text = text.replace("go to:abstract","")
    text = text.replace("go to:summary","")
    #removing last keywords as not needed using regex
    text = re.sub("\.keywords:.+","",text)
    return text.strip()

data.text = data.text.apply(lambda x : structure_1(x))

# %%
# data.to_csv('last_5_final.csv')
data.head()
# Out:
#    Unnamed: 0                         doi        pmid  \
# 0           0   10.1377/hlthaff.2014.0743  25489031.0
# 1           1     10.7508/ibj.2015.03.009  26025954.0
# 2           2     10.3748/wjg.v21.i8.2504  25741161.0
# 3           3  10.4103/ijnmr.IJNMR_174_18  31333744.0
# 4           4   10.1136/bmjpo-2017-000172  29637168.0
#
#                                                 text  \
# 0  the aca establishes “essential health benefits...
# 1  background:the variable numbers of tandem-repe...
# 2  aim: to evaluate the safety and efficacy of te...
# 3  background:cancer is the second most common ca...
# 4  objectiveto describe the experiences of austra...
#
#                                                 link    label1
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  abstract
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  abstract

# %%
data['numerics'] = data.text.apply(lambda x: len([x for x in x.split() if x.isdigit()]))
data.head()
# Out:
#    Unnamed: 0                         doi        pmid  \
# 0           0   10.1377/hlthaff.2014.0743  25489031.0
# 1           1     10.7508/ibj.2015.03.009  26025954.0
# 2           2     10.3748/wjg.v21.i8.2504  25741161.0
# 3           3  10.4103/ijnmr.IJNMR_174_18  31333744.0
# 4           4   10.1136/bmjpo-2017-000172  29637168.0
#
#                                                 text  \
# 0  the aca establishes “essential health benefits...
# 1  background:the variable numbers of tandem-repe...
# 2  aim: to evaluate the safety and efficacy of te...
# 3  background:cancer is the second most common ca...
# 4  objectiveto describe the experiences of austra...
#
#                                                 link    label1  numerics
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         2
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         3
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         6
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  abstract         3
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  abstract         4

# %%
# data.numerics.tolist()

# %%
def r_stopwords(text):
    """only extracting alphabets, eliminating all punctuation and numbers"""
#     text = re.sub('\W+',' ',text)
    text = re.sub('[^a-zA-Z]+',' ',text)
#     text = te.sub('[0-9]')
    return text.strip()

#data.text = data.text.apply(lambda x : r_stopwords(x))
data.text = data.text.apply(lambda x : r_stopwords(x))
data.head()
# Out:
#    Unnamed: 0                         doi        pmid  \
# 0           0   10.1377/hlthaff.2014.0743  25489031.0
# 1           1     10.7508/ibj.2015.03.009  26025954.0
# 2           2     10.3748/wjg.v21.i8.2504  25741161.0
# 3           3  10.4103/ijnmr.IJNMR_174_18  31333744.0
# 4           4   10.1136/bmjpo-2017-000172  29637168.0
#
#                                                 text  \
# 0  the aca establishes essential health benefits ...
# 1  background the variable numbers of tandem repe...
# 2  aim to evaluate the safety and efficacy of ten...
# 3  background cancer is the second most common ca...
# 4  objectiveto describe the experiences of austra...
#
#                                                 link    label1  numerics
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         2
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         3
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         6
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  abstract         3
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  abstract         4

# %%
import nltk
from nltk.stem import WordNetLemmatizer 
lemmatizer = WordNetLemmatizer() 

def clean(text):
    text = [lemmatizer.lemmatize(t) for t in text.split(' ')]
    text = text_cleaner.abs_clean(text, per_dict=False) 
    """abs_clean -> clean stopwords
                 -> clean distorted or irrelavent words using regex
                 -> clean verbs using spacy library
                 -> clean text with personnel dictionary if per_dict=True
                     #True - doesnt give good clusters, no elbow found in elbow method 
                     #False - good to go
                 -> final
                 #for further, see cleaner in material_Cleaner folder"""
    
    return text
data.text = data.text.apply(lambda x : clean(x))
data.head()
# Out:
#    Unnamed: 0                         doi        pmid  \
# 0           0   10.1377/hlthaff.2014.0743  25489031.0
# 1           1     10.7508/ibj.2015.03.009  26025954.0
# 2           2     10.3748/wjg.v21.i8.2504  25741161.0
# 3           3  10.4103/ijnmr.IJNMR_174_18  31333744.0
# 4           4   10.1136/bmjpo-2017-000172  29637168.0
#
#                                                 text  \
# 0  neither insurance important although essential...
# 1  diagnosis tandem respectively frequent number ...
# 2  growth alt beijing perinatal live ldt also fet...
# 3  respectively resilience time two strategy anov...
# 4  relevant physician portal practice representat...
#
#                                                 link    label1  numerics
# 0  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         2
# 1  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         3
# 2  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4...  abstract         6
# 3  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC6...  abstract         3
# 4  https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5...  abstract         4

# %%
#list of documents 
documents = data.text.tolist()

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans

def process_text(text):
    """tokenise text on space, othrwise tdidf will have its by-default tokeniser"""
    words = text.split(' ') 
    return words
    

vectorizer = TfidfVectorizer( tokenizer = process_text,stop_words='english', max_df=0.7) #
doc_vec = vectorizer.fit_transform(documents)

# %%
dtm = pd.DataFrame(doc_vec.toarray().transpose(), index = vectorizer.get_feature_names(), columns= data.doi.tolist())
arr = np.array(dtm)

# %%
import matplotlib.pyplot as plt
# Using the elbow method to find the optimal number of clusters
from sklearn.cluster import KMeans
# %matplotlib inline  
wcss = []
for i in range(1, 15):
    kmeans = KMeans(n_clusters = i, init = 'random', random_state = 40,max_iter = 100, n_init = 1) #random,k-means++
    kmeans.fit(arr)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 15), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
#n = 5, 6,10

# %%
# # no. of cluster == 5, 6, 10
# n=10
# model = KMeans(n_clusters=n, init='k-means++', max_iter = 100, n_init = 10)
# model.fit(arr)

# import string
# import collections
# clustering = collections.defaultdict(list)
 
# for idx, label in enumerate(model.labels_):
#     clustering[label].append(dtm.index[idx])

# %%
# n=5
# model = KMeans(n_clusters=n, init='k-means++', max_iter = 100, n_init = 10)
# model.fit(doc_vec.transpose())
# terms = vectorizer.get_feature_names()
# import string
# import collections
# clustering = collections.defaultdict(list)
 
# for idx, label in enumerate(model.labels_):
#     clustering[label].append(terms[idx])
# #print(dict(clustering))

# %%
import collections
import os
import time

def cluster(min=4,max=15,directory=str(time.time()).split('.')[0], km_init = "k-means++"):
    terms = vectorizer.get_feature_names()
    for n in range(min,max):
        model = KMeans(n_clusters=n, init=km_init, max_iter = 100, n_init=10)
        model.fit(doc_vec.transpose())

        clustering = collections.defaultdict(list)

        for idx, label in enumerate(model.labels_):
            clustering[label].append(terms[idx]) 
        if not os.path.isdir(directory):
            os.mkdir(directory)
        filename = "df_"+str(n)

        df = pd.DataFrame(columns = ('cluster_n','keywords','no.of words'))

        for key, value in clustering.items():
            cluster = key
            keyword =  ' '.join(value)
            length = len(value)

            df = df.append({'cluster_n':cluster,'keywords':str(keyword),'no.of words':length},ignore_index=True)
        df.to_excel(os.path.join(directory,filename+'.xlsx'))

# %%
cluster(min=2,max=8, km_init="k-means++", directory = "kmeans_per_dict") # give directory == directoryname  , km_init = ['random' or 'k-means++']
"""It will save all cluster with in range given in min and max, to directory name given or bydefault timestamp directory"""
